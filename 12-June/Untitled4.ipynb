# %%
import pandas as pd
df = pd.read_csv('price1.csv')

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(df.drop('price', axis='columns'), df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  7108.36866057, -58328.54711629,  -1705.7522849 ])

# %%
model.predict([[1000,3,12]])
# Out:
# C:\Users\Prinshi\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4028945.40687047])

# %%
df1 = pd.read_csv('price.csv')

# %%
df1
# Out:
#     area    price
# 0    550  1000000
# 1    600  1200000
# 2    650  1500000
# 3    700  2000000
# 4    750  2300000
# 5    800  2620000
# 6    850  2960000
# 7    900  3300000
# 8    950  3640000
# 9   1000  3980000
# 10  1050  4320000
# 11  1100  4660000
# 12  1150  5000000
# 13  1200  5340000
# 14  1250  5680000
# 15  1300  6020000

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(df.drop('price', axis='columns'), df.price)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
a = df

# %%
a.locality = le.fit_transform(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a.locality = le.fit_transform(df1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_label.py:114, in LabelEncoder.fit_transform(self, y)
#     101 def fit_transform(self, y):
#     102     """Fit label encoder and return encoded labels.
#     103
#     104     Parameters
#    (...)
#     112         Encoded labels.
#     113     """
# --> 114     y = column_or_1d(y, warn=True)
#     115     self.classes_, y = _unique(y, return_inverse=True)
#     116     return y
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1377, in column_or_1d(y, dtype, warn)
#    1366         warnings.warn(
#    1367             (
#    1368                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1373             stacklevel=2,
#    1374         )
#    1375     return _asarray_with_order(xp.reshape(y, (-1,)), order="C", xp=xp)
# -> 1377 raise ValueError(
#    1378     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1379 )
#
# ValueError: y should be a 1d array, got an array of shape (16, 2) instead.
