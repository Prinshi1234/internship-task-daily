# %%
import pandas as pd
df = pd.read_csv('gen.csv')

# %%
df
# Out:
#    height gender
# 0     152      F
# 1     165      M
# 2     167      M
# 3     172      M
# 4     171      M
# 5     156      F
# 6     160      F
# 7     173      M
# 8     155      F

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df
a.gender = le.fit_transform(a.gender)

# %%
a
# Out:
#    height  gender
# 0     152       0
# 1     165       1
# 2     167       1
# 3     172       1
# 4     171       1
# 5     156       0
# 6     160       0
# 7     173       1
# 8     155       0

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(a.drop('gender', axis ='columns'),a.gender)
# Out:
# LogisticRegression()

# %%
model.predict([[161]])
# Out:
# C:\Users\Prinshi\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
 x = int(input('height'))
# Out:
# height 155

# %%
y = model.predict([[x]])
# Out:
# C:\Users\Prinshi\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if(y):print('Male')
else:print('Female')
# Out:
# Female

# %%
x = int(input('height'))
y= model.predict([[x]])
if(y):print('Male')
else:print('Female')
# Out:
# height 170
# Male
# C:\Users\Prinshi\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
