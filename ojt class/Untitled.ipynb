# %%
hours = [[2],[3],[4],[5],[6],[7]]
marks = [46,50,57,68,76,81]
import pandas as pd
df = pd.DataFrame(hours,marks)
df.to_csv('marks.csv')

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#     0
# 46  2
# 50  3
# 57  4
# 68  5
# 76  6
# 81  7

# %%
plt.scatter(hours,marks)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.regplot(x=hours, y = marks, color='red' )
# Out:
# <Axes: >

# %%
import sklearn.linear_model

# %%
regressor = sklearn.linear_model.LinearRegression()

# %%
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(hours,marks)
# Out:
# LinearRegression()

# %%
a = [9,3,5,6,]
a[3]
# Out:
# 6

# %%
a = [[9,3,5,6,],[8,6,7,5]]
a[1]
# Out:
# [8, 6, 7, 5]

# %%
a[0][1]
# Out:
# 3

# %%
import pickle as pkl

# %%
pkl.dump(regressor, open('a.pkl','wb'))
hours_test = [[8]]

# %%
marks_pred = regressor.predict(x_test)

# %%
marks_pred
# Out:
# array([700.37142857,  89.4       ])

# %%
df1 = pd.DataFrame({'orignal':hours_test},{'predicted':marks_pred})
df1
# Out:
#           orignal
# predicted     [8]

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
regressor.predict([[8.5]])
# Out:
# array([93.17142857])
